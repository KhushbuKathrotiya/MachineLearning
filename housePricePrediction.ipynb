# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("./homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area (sqr ft)')
plt.ylabel('prices (US$)')
plt.scatter(df.area,df.price, color ='red', marker='+')

# %%
# creating object for linear regression

reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /Users/khushbu/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# import new csv with area
area_df = pd.read_csv("areas.csv")
area_df.head(3)

# predict the price
p = reg.predict(area_df)
p

# add new column in your data
area_df['prices']=p
area_df

#import to csv

area_df.to_csv("prediction.csv", index = False)

# %%
# %matplotlib inline
plt.xlabel('area (sqr ft)', fontsize=20)
plt.ylabel('prices (US$)',fontsize=20)

plt.scatter(df.area,df.price, color ='red', marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
